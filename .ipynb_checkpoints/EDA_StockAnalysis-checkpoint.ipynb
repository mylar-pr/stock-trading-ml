# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from pandas_datareader.data import DataReader
from datetime import datetime

# %%
# The tech stocks we'll be using are Pfizer, Moderna, J&J, Merck
tech_list = ['PFE', 'MRNA', 'JNJ', "MRK"]

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)


#For loop for getting the stock data
for stock in tech_list:   
    globals()[stock] = DataReader(stock, 'yahoo', start, end)

# %%
company_list = [PFE, MRNA, JNJ, MRK]
company_name = ["Pfizer", "MODERNA", "Johnson & Johnson", "MERCK"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.sample(10)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-01-05   81.400002   79.910004   80.669998   81.099998  10454700.0
# 2020-07-08   62.459999   59.450001   60.790001   61.580002   7590900.0
# 2021-02-26   74.709999   72.540001   74.440002   72.620003  16833900.0
# 2021-03-25  162.449997  160.639999  162.440002  161.970001   6269800.0
# 2021-03-26   77.470001   75.849998   76.150002   77.389999   9906000.0
# 2020-09-02  154.330002  149.250000  150.789993  153.830002   6881900.0
# 2020-11-05   71.589996   70.160004   71.089996   71.480003   4449900.0
# 2021-02-16  167.050003  164.639999  166.580002  165.070007   5656100.0
# 2020-06-12   77.930000   75.470001   77.889999   76.300003  16222000.0
# 2020-09-10   60.320000   56.869999   57.041000   57.560001   7985300.0
#
#              Adj Close       company_name
# Date
# 2021-01-05   80.393646              MERCK
# 2020-07-08   61.580002            MODERNA
# 2021-02-26   71.987511              MERCK
# ...

# %%
# To see a historical view of the closing price. For historical view we'll be using Adj. Closing price

plt.figure(figsize=(12, 8))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"{tech_list[i - 1]}")

# %%
#Moving Average
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
df.groupby("company_name").hist(figsize=(12, 12));

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

PFE[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('Pfizer')

MRNA[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('MODERNA')

JNJ[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('Johnson & Johnson')

MRK[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('MERCK')

fig.tight_layout()

# %%
# We have used pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# To plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

PFE['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('Pfizer')

MRNA['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('MODERNA')

JNJ['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('J&J')

MRK['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('MERCK')

fig.tight_layout()

# %%
# To get a better view of above chart
plt.figure(figsize=(12, 12))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    sns.distplot(company['Daily Return'].dropna(), bins=100, color='blue')
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')

# %%
# Creating a new DataFrame for Closing prices
closing_df = DataReader(tech_list, 'yahoo', start, end)['Adj Close']
closing_df.head()
# Out:
# Symbols           PFE       MRNA         JNJ        MRK
# Date
# 2020-04-22  33.021290  51.200001  148.961761  77.478355
# 2020-04-23  33.422100  47.439999  151.415421  78.350189
# 2020-04-24  34.050648  50.500000  150.782532  78.882996
# 2020-04-27  34.916031  48.049999  150.227539  81.353249
# 2020-04-28  34.533443  47.880001  147.403900  78.640816

# %%
# Making a new DataFrame for returns
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# Symbols          PFE      MRNA       JNJ       MRK
# Date
# 2020-04-22       NaN       NaN       NaN       NaN
# 2020-04-23  0.012138 -0.073438  0.016472  0.011253
# 2020-04-24  0.018806  0.064503 -0.004180  0.006800
# 2020-04-27  0.025415 -0.048515 -0.003681  0.031315
# 2020-04-28 -0.010957 -0.003538 -0.018796 -0.033341

# %%
# Comparing Pfizer to itself should show a perfectly linear relationship
sns.jointplot('PFE', 'PFE', tech_rets, kind='scatter', color='blue')

# %%
sns.pairplot(tech_rets, kind='reg')

# %%
return_fig = sns.PairGrid(tech_rets.dropna())

return_fig.map_upper(plt.scatter, color='blue')

return_fig.map_lower(plt.scatter, cmap='blue')

return_fig.map_diag(plt.hist, bins=30)

# %%
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='blue')

returns_fig.map_lower(plt.scatter,cmap='cool_d')

returns_fig.map_diag(plt.hist,bins=30)

# %%
sns.heatmap(tech_rets.corr(), annot=True, cmap='Reds')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='Reds')

# %%
rets = tech_rets.dropna()

area = np.pi*20

plt.figure(figsize=(12, 10))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))
