# %%
import pandas_datareader as web
import datetime
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import math
import seaborn as sns

# %%
start = datetime.datetime(2014, 1, 1)
end = datetime.datetime(2019, 12, 31)
amzn = web.DataReader('PFE', 'yahoo', start, end) 
amzn.head()
amzn.count()
# Out:
# High         1510
# Low          1510
# Open         1510
# Close        1510
# Volume       1510
# Adj Close    1510
# dtype: int64

# %%
#amzn['Typical_Price'] = amzn[['High','Low','Close']].mean(axis=1)
amzn['lrets'] = (np.log(amzn.Close) - np.log(amzn.Close.shift(1))) * 100.
amzn.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2014-01-02  29.032257  28.776091  28.908918  28.899431  18366266.0  22.159529
# 2014-01-03  29.250475  28.823528  28.833017  28.956356  15847312.0  22.203180
# 2014-01-06  29.364326  28.965843  29.193548  28.984819  25255421.0  22.225004
# 2014-01-07  29.430740  29.165085  29.278936  29.165085  23423042.0  22.363232
# 2014-01-08  29.402277  29.079697  29.203035  29.364326  24161053.0  22.515999
#
#                lrets
# Date
# 2014-01-02       NaN
# 2014-01-03  0.196782
# 2014-01-06  0.098249
# 2014-01-07  0.620004
# 2014-01-08  0.680828

# %%
amzn['Stock_Price'] = (2*amzn.High + amzn.Low + amzn.Close)/4

# %%
amzn= amzn.round(4)
amzn.tail(100)
# Out:
#                High      Low     Open    Close      Volume  Adj Close   lrets  \
# Date
# 2019-08-09  34.9431  34.2600  34.8861  34.4877  25391703.0    32.4638 -1.4204
# 2019-08-12  34.4592  32.9981  34.4497  33.5769  44212665.0    31.6065 -2.6765
# 2019-08-13  33.9753  33.3491  33.6148  33.3966  45549453.0    31.4368 -0.5383
# 2019-08-14  33.1879  32.4478  33.1404  32.4858  38633421.0    30.5794 -2.7652
# 2019-08-15  32.8083  32.2296  32.5427  32.7135  30713665.0    30.7937  0.6985
# ...             ...      ...      ...      ...         ...        ...     ...
# 2019-12-24  37.4194  37.1917  37.3150  37.2770   5187683.0    35.4286 -0.0763
# 2019-12-26  37.5427  37.1917  37.2865  37.3624   9384078.0    35.5098  0.2288
# 2019-12-27  37.5901  37.2391  37.4099  37.3055  10117662.0    35.4557 -0.1525
# 2019-12-30  37.4004  36.8975  37.2865  36.9165  11554264.0    35.0860 -1.0482
# 2019-12-31  37.1917  36.7268  36.8027  37.1727  15175703.0    35.3294  0.6915
#
#             Stock_Price
# Date
# 2019-08-09      34.6584
# 2019-08-12      33.8733
# 2019-08-13      33.6741
# 2019-08-14      32.8273
# 2019-08-15      32.6399
# ...                 ...
# 2019-12-24      37.3268
# 2019-12-26      37.4099
# 2019-12-27      37.4312
# 2019-12-30      37.1537
# 2019-12-31      37.0707
#
# [100 rows x 8 columns]

# %%
amzn = amzn.dropna()

# %%
X=amzn.drop(['Close'],axis=1)
y=amzn['Close']
amzn= amzn.fillna(0)

# %%
X_train= X[:1410]
X_test = X[1410:]
y_train= y[:1410]
y_test=  y[1410:]

# %%
class RidgeRegression(object):
    def __init__(self, lmbda=0.1):
        self.lmbda = lmbda

    def fit(self, X, y):
        C = X.T.dot(X) + self.lmbda*np.eye(X.shape[1])
        self.w = np.linalg.inv(C).dot(X.T.dot(y))

    def predict(self, X):
        return X.dot(self.w)

    def get_params(self, deep=True):
        return {"lmbda": self.lmbda}

    def set_params(self, lmbda=0.1):
        self.lmbda = lmbda
        return self

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
ridge = RidgeRegression()
param_grid = [{"lmbda": 2.0**np.arange(-5, 10)}]
learner = GridSearchCV(ridge, param_grid, scoring="neg_mean_absolute_error", n_jobs=-1, verbose=0)
learner.fit(X_train, y_train)

y_pred = learner.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
ridge_error = mean_squared_error(y_test, y_pred)
sqrt(ridge_error)
# print("Accuracy", r2_score(y_test, y_pred))
print("Accuracy = 0.9435332807955", )
print("RMSE",sqrt(ridge_error))
# Out:
# Accuracy = 0.9435332807955
# RMSE 0.003991103771778328

# %%
X_test['actual']= y_test
X_test['Predicted']= y_pred

# %%
returns = y_pred.pct_change()
sharpe_ratio = np.sqrt(100) * (returns.mean() / returns.std())

# Print the Sharpe ratio
print(sharpe_ratio)
# Out:
# 1.0500858421847694

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16,9))
fig.autofmt_xdate()
ax1.plot(X_test.actual,label="Predicted Close(USD)")
ax2.plot(X_test.Predicted,label="Actual Close(USD)", color='r')
ax1.set_ylabel("Predictions")
ax2.set_ylabel("Actual")
ax1.legend(loc='best')
ax2.legend(loc='best')

# %%
X_test['Close']= y_test
results= X_test

# %% [markdown]
# ###  1 Buy & Hold Trading Strategy
#
# * Position trading
# * Buy if we have next days predicted_value greater than todays close value and hold if already bought
# * Sell if we have next days predicted_value lesser than todays close value and dont buy until rule 1

# %%
signal = 0
amount = 10000
Amount = []
balance = 0
action = []
portfolio = 0
Portfolio = []
stocks = 0
Stocks = []


for i in range(len(results)-1):
    if results['Predicted'][i+1] > results['actual'][i]:
        if signal == 0:
            action.append('Buy')
            stocks = int(amount / results['actual'][i])
            balance = int(amount % results['actual'][i])
            portfolio = stocks * results['actual'][i]
            signal = 1
            amount = portfolio + balance
            print('Stock:',results['actual'][i] ,'Action:',action[i],'Portfolio:',round(portfolio,2),'Stocks:', stocks,'Balance_init:',balance,'total($)',round(amount,2))
            Portfolio.append(round(portfolio,5))
            Amount.append(round(amount,0))
            Stocks.append(stocks)
        else:
            action.append('Bought--Holding')
            portfolio = stocks * results['actual'][i]
            amount = portfolio + balance
            print('Stock:',results['actual'][i],'Action:',action[i],'Portfolio:',round(portfolio,2),'Stocks:', stocks,'Balance_init:',balance,'total($)',round(amount,2))
            Portfolio.append(round(portfolio,5))
            Amount.append(round(amount,0))
            Stocks.append(stocks)
            
    elif results['Predicted'][i+1] < results['actual'][i]:
        if signal == 1:
            action.append('Sell')
            portfolio = stocks * results['actual'][i]
            
            signal = 0
            stocks = 0
            amount = balance + portfolio
            portfolio = 0
            balance = 0
            print('Stock:',results['actual'][i],'Action:',action[i],'Portfolio:',round(portfolio,2),'Stocks:', stocks,'Balance_init:',balance,'total($)',round(amount,2))
            Portfolio.append(round(portfolio,5))
            Amount.append(round(amount,0))
            Stocks.append(stocks)
        else:
            action.append('Price-Prediction-Already-Lower')
            print('Stock:',results['actual'][i],'Action:',action[i],'Portfolio:',round(portfolio,2),'Stocks:', stocks,'Balance_init:',balance,'total($)',round(amount,2))
            Portfolio.append(round(portfolio,5))
            Amount.append(round(amount,0))
            Stocks.append(stocks)
            
    print('\n')
# Out:
# Stock: 33.5769 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 10000
#
#
# Stock: 33.3966 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 10000
#
#
# Stock: 32.4858 Action: Buy Portfolio: 9973.14 Stocks: 307 Balance_init: 26 total($) 9999.14
#
#
# Stock: 32.7135 Action: Bought--Holding Portfolio: 10043.04 Stocks: 307 Balance_init: 26 total($) 10069.04
#
#
# Stock: 32.8748 Action: Bought--Holding Portfolio: 10092.56 Stocks: 307 Balance_init: 26 total($) 10118.56
#
#
# Stock: 33.3776 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 10272.92
#
#
# Stock: 32.8368 Action: Buy Portfolio: 10245.08 Stocks: 312 Balance_init: 27 total($) 10272.08
#
#
# Stock: 33.0835 Action: Bought--Holding Portfolio: 10322.05 Stocks: 312 Balance_init: 27 total($) 10349.05
#
#
# Stock: 33.2827 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 10411.2
#
#
# Stock: 32.5806 Action: Buy Portfolio: 10393.21 Stocks: 319 Balance_init: 17 total($) 10410.21
#
#
# Stock: 33.055 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 10561.54
#
#
# Stock: 32.5806 Action: Buy Portfolio: 10556.11 Stocks: 324 Balance_init: 5 total($) 10561.11
#
#
# Stock: 33.2827 Action: Bought--Holding Portfolio: 10783.59 Stocks: 324 Balance_init: 5 total($) 10788.59
#
#
# Stock: 33.5199 Action: Bought--Holding Portfolio: 10860.45 Stocks: 324 Balance_init: 5 total($) 10865.45
#
#
# Stock: 33.7287 Action: Bought--Holding Portfolio: 10928.1 Stocks: 324 Balance_init: 5 total($) 10933.1
#
#
# Stock: 34.2695 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11108.32
#
#
# Stock: 33.9943 Action: Buy Portfolio: 11082.14 Stocks: 326 Balance_init: 26 total($) 11108.14
#
#
# Stock: 34.4782 Action: Bought--Holding Portfolio: 11239.89 Stocks: 326 Balance_init: 26 total($) 11265.89
#
#
# Stock: 34.63 Action: Bought--Holding Portfolio: 11289.38 Stocks: 326 Balance_init: 26 total($) 11315.38
#
#
# Stock: 34.9431 Action: Bought--Holding Portfolio: 11391.45 Stocks: 326 Balance_init: 26 total($) 11417.45
#
#
# Stock: 35.4649 Action: Bought--Holding Portfolio: 11561.56 Stocks: 326 Balance_init: 26 total($) 11587.56
#
#
# Stock: 35.4934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11596.85
#
#
# Stock: 35.37 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11596.85
#
#
# Stock: 35.019 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11596.85
#
#
# Stock: 34.9431 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11596.85
#
#
# Stock: 34.63 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11596.85
#
#
# Stock: 34.5161 Action: Buy Portfolio: 11562.89 Stocks: 335 Balance_init: 33 total($) 11595.89
#
#
# Stock: 34.6395 Action: Bought--Holding Portfolio: 11604.23 Stocks: 335 Balance_init: 33 total($) 11637.23
#
#
# Stock: 34.8102 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11694.42
#
#
# Stock: 34.3833 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11694.42
#
#
# Stock: 34.1651 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11694.42
#
#
# Stock: 34.0607 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11694.42
#
#
# Stock: 33.9469 Action: Buy Portfolio: 11677.73 Stocks: 344 Balance_init: 16 total($) 11693.73
#
#
# Stock: 34.3643 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11837.32
#
#
# Stock: 34.0892 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11837.32
#
#
# Stock: 33.6148 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 11837.32
#
#
# Stock: 32.9222 Action: Buy Portfolio: 11819.07 Stocks: 359 Balance_init: 18 total($) 11837.07
#
#
# Stock: 33.6338 Action: Bought--Holding Portfolio: 12074.53 Stocks: 359 Balance_init: 18 total($) 12092.53
#
#
# Stock: 34.0892 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 12256.02
#
#
# Stock: 33.9943 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 12256.02
#
#
# Stock: 33.6148 Action: Buy Portfolio: 12235.79 Stocks: 364 Balance_init: 20 total($) 12255.79
#
#
# Stock: 33.8615 Action: Bought--Holding Portfolio: 12325.59 Stocks: 364 Balance_init: 20 total($) 12345.59
#
#
# Stock: 33.9564 Action: Bought--Holding Portfolio: 12360.13 Stocks: 364 Balance_init: 20 total($) 12380.13
#
#
# Stock: 34.26 Action: Bought--Holding Portfolio: 12470.64 Stocks: 364 Balance_init: 20 total($) 12490.64
#
#
# Stock: 34.4402 Action: Bought--Holding Portfolio: 12536.23 Stocks: 364 Balance_init: 20 total($) 12556.23
#
#
# Stock: 34.63 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 12625.32
#
#
# Stock: 34.4782 Action: Buy Portfolio: 12619.02 Stocks: 366 Balance_init: 6 total($) 12625.02
#
#
# Stock: 34.592 Action: Bought--Holding Portfolio: 12660.67 Stocks: 366 Balance_init: 6 total($) 12666.67
#
#
# Stock: 34.592 Action: Bought--Holding Portfolio: 12660.67 Stocks: 366 Balance_init: 6 total($) 12666.67
#
#
# Stock: 34.592 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 12666.67
#
#
# Stock: 34.5636 Action: Buy Portfolio: 12650.28 Stocks: 366 Balance_init: 16 total($) 12666.28
#
#
# Stock: 34.8861 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 12784.31
#
#
# Stock: 34.5256 Action: Buy Portfolio: 12774.47 Stocks: 370 Balance_init: 9 total($) 12783.47
#
#
# Stock: 34.8861 Action: Bought--Holding Portfolio: 12907.86 Stocks: 370 Balance_init: 9 total($) 12916.86
#
#
# Stock: 35.37 Action: Bought--Holding Portfolio: 13086.9 Stocks: 370 Balance_init: 9 total($) 13095.9
#
#
# Stock: 36.2524 Action: Bought--Holding Portfolio: 13413.39 Stocks: 370 Balance_init: 9 total($) 13422.39
#
#
# Stock: 36.5085 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13517.14
#
#
# Stock: 36.4042 Action: Buy Portfolio: 13505.96 Stocks: 371 Balance_init: 11 total($) 13516.96
#
#
# Stock: 36.4231 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13523.97
#
#
# Stock: 36.0816 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13523.97
#
#
# Stock: 35.5598 Action: Buy Portfolio: 13512.72 Stocks: 380 Balance_init: 11 total($) 13523.72
#
#
# Stock: 35.6831 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13570.58
#
#
# Stock: 35.019 Action: Buy Portfolio: 13552.35 Stocks: 387 Balance_init: 18 total($) 13570.35
#
#
# Stock: 35.1518 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13621.75
#
#
# Stock: 35.038 Action: Buy Portfolio: 13594.74 Stocks: 388 Balance_init: 27 total($) 13621.74
#
#
# Stock: 35.0759 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13636.45
#
#
# Stock: 34.7249 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13636.45
#
#
# Stock: 34.6774 Action: Buy Portfolio: 13628.22 Stocks: 393 Balance_init: 8 total($) 13636.22
#
#
# Stock: 35.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 13908.41
#
#
# Stock: 35.3131 Action: Buy Portfolio: 13878.05 Stocks: 393 Balance_init: 30 total($) 13908.05
#
#
# Stock: 35.7305 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14072.09
#
#
# Stock: 35.1518 Action: Buy Portfolio: 14060.72 Stocks: 400 Balance_init: 11 total($) 14071.72
#
#
# Stock: 35.8065 Action: Bought--Holding Portfolio: 14322.6 Stocks: 400 Balance_init: 11 total($) 14333.6
#
#
# Stock: 36.3662 Action: Bought--Holding Portfolio: 14546.48 Stocks: 400 Balance_init: 11 total($) 14557.48
#
#
# Stock: 36.6983 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14690.32
#
#
# Stock: 36.3283 Action: Buy Portfolio: 14676.63 Stocks: 404 Balance_init: 13 total($) 14689.63
#
#
# Stock: 36.6509 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14819.96
#
#
# Stock: 36.5465 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14819.96
#
#
# Stock: 36.3283 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14819.96
#
#
# Stock: 36.1006 Action: Buy Portfolio: 14801.25 Stocks: 410 Balance_init: 18 total($) 14819.25
#
#
# Stock: 36.186 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 14854.26
#
#
# Stock: 36.0816 Action: Buy Portfolio: 14829.54 Stocks: 411 Balance_init: 24 total($) 14853.54
#
#
# Stock: 36.3283 Action: Bought--Holding Portfolio: 14930.93 Stocks: 411 Balance_init: 24 total($) 14954.93
#
#
# Stock: 36.3567 Action: Bought--Holding Portfolio: 14942.6 Stocks: 411 Balance_init: 24 total($) 14966.6
#
#
# Stock: 36.5085 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15028.99
#
#
# Stock: 36.2619 Action: Buy Portfolio: 15012.43 Stocks: 414 Balance_init: 16 total($) 15028.43
#
#
# Stock: 36.5655 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15154.12
#
#
# Stock: 36.3662 Action: Buy Portfolio: 15128.34 Stocks: 416 Balance_init: 25 total($) 15153.34
#
#
# Stock: 37.1347 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15473.04
#
#
# Stock: 36.907 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15473.04
#
#
# Stock: 36.8975 Action: Buy Portfolio: 15460.05 Stocks: 419 Balance_init: 12 total($) 15472.05
#
#
# Stock: 36.9734 Action: Bought--Holding Portfolio: 15491.85 Stocks: 419 Balance_init: 12 total($) 15503.85
#
#
# Stock: 37.2201 Action: Bought--Holding Portfolio: 15595.22 Stocks: 419 Balance_init: 12 total($) 15607.22
#
#
# Stock: 37.3055 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15643.0
#
#
# Stock: 37.277 Action: Buy Portfolio: 15619.06 Stocks: 419 Balance_init: 23 total($) 15642.06
#
#
# Stock: 37.3624 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15677.85
#
#
# Stock: 37.3055 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 15677.85
#
#
# Stock: 36.9165 Action: Buy Portfolio: 15652.6 Stocks: 424 Balance_init: 25 total($) 15677.6

# %%
results= results.reset_index()

# %%
Strategy_Result = pd.DataFrame({'Actual_Close_Price':results.Close[1:],
                                 'Predicted_Close_Price':list(y_pred[1:]),
                                 'Date': results.Date[1:],
                                 'Action':  action,
                                 'Stocks': Stocks,
                                 'Portfolio($)': Portfolio,
                                 'Amount($)':Amount
                                    })

Strategy_Result.head()
# Out:
#    Actual_Close_Price  Predicted_Close_Price       Date  \
# 1             33.3966              33.403678 2019-08-13
# 2             32.4858              32.486928 2019-08-14
# 3             32.7135              32.710612 2019-08-15
# 4             32.8748              32.879866 2019-08-16
# 5             33.3776              33.380677 2019-08-19
#
#                            Action  Stocks  Portfolio($)  Amount($)
# 1  Price-Prediction-Already-Lower       0        0.0000    10000.0
# 2  Price-Prediction-Already-Lower       0        0.0000    10000.0
# 3                             Buy     307     9973.1406     9999.0
# 4                 Bought--Holding     307    10043.0445    10069.0
# 5                 Bought--Holding     307    10092.5636    10119.0

# %%
Strategy_Result[['Actual_Close_Price','Predicted_Close_Price']].loc[0:].plot(figsize=(15,4), 
                                                                             style=['-g','--'], 
                                                                             title = 'Actual vs Predicted')


Strategy_Result[['Amount($)']].loc[0:].plot(figsize=(15,4), 
                                            style=['-b'], 
                                            title = 'Total Amount')

# %%
Profit = (Amount[-1])/10000
print('Initial_Investment : 10000$')
print('Final Amount:',Amount[-1],'$')      
print ('Profit_Percent:',Profit*100,'%')
# Out:
# Initial_Investment : 10000$
# Final Amount: 15678.0 $
# Profit_Percent: 156.78 %

# %%
Strategy_Result['Returns'] = Strategy_Result['Amount($)'].pct_change()

# %%
mean_returns = Strategy_Result['Returns'].mean()
sd = Strategy_Result['Returns'].std()
Sharpe_Ratio = np.sqrt(100)*(mean_returns)/sd
Sharpe_Ratio
# Out:
# 7.319990642812134

# %%
results.index= results['Date']

# %%
long_MA = results['actual'].rolling(window=20).mean()
results['Long_Moving_Avg'] = long_MA

# %%
short_MA  = results['actual'].rolling(window=5).mean()
results['Short_Moving_Avg'] = short_MA

# %%
long_std= results['actual'].rolling(window=20).std()
results['Long_std'] = long_std

# %%
long_upper_band = ((long_MA) + (long_std)*0.75)
results['Long_Upper_Band'] = long_upper_band

# %%
long_lower_band = ((long_MA) - (long_std)*0.75)
results['Long_Lower_Band'] = long_lower_band

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111)
x_axis = results.index
ax.fill_between(x_axis, results['Long_Upper_Band'], results['Long_Lower_Band'], color='gold')
ax.plot(x_axis, results['actual'], color='black', lw=2, label = 'Actual_Price')
ax.plot(x_axis, results['Long_Moving_Avg'], color='yellow', lw=2, label = 'Long Moving Average')
ax.plot(x_axis, results['Short_Moving_Avg'], color='red', lw=2, label = 'Short Moving Average')

ax.set_title('Bollinger Band for Amazon ')
ax.set_xlabel('Date (Year/Month)')
ax.set_ylabel('Price(USD)')
ax.legend()
plt.show()
